-- %%
%sql
SELECT *
FROM read_files(
  '/Volumes/workspace/bronze/source_system/source_crm/cust_info.csv',
  format => 'csv',
  header => true
);

-- %%
%sql
CREATE OR REPLACE TABLE workspace.bronze.cust_info_bronze AS
SELECT *
FROM read_files(
  '/Volumes/workspace/bronze/source_system/source_crm/cust_info.csv',
  format => 'csv',
  header => true
);

-- %%
%sql
SELECT *
FROM workspace.bronze.cust_info_bronze;

-- %%
%sql
CREATE OR REPLACE TABLE workspace.bronze.prd_info_bronze AS
SELECT *
FROM read_files(
  '/Volumes/workspace/bronze/source_system/source_crm/prd_info.csv',
  format => 'csv',
  header => true
);

-- %%
%sql
CREATE OR REPLACE TABLE workspace.bronze.sales_details_bronze AS
SELECT *
FROM read_files(
  '/Volumes/workspace/bronze/source_system/source_crm/sales_details.csv',
  format => 'csv',
  header => true
);

-- %%
%sql
CREATE OR REPLACE TABLE workspace.bronze.CUST_AZ12_bronze AS
SELECT *
FROM read_files(
  '/Volumes/workspace/bronze/source_system/source_erp/CUST_AZ12.csv',
  format => 'csv',
  header => true
);

-- %%
%sql
CREATE OR REPLACE TABLE workspace.bronze.LOC_A101_bronze AS
SELECT *
FROM read_files(
  '/Volumes/workspace/bronze/source_system/source_erp/LOC_A101.csv',
  format => 'csv',
  header => true
);

-- %%
%sql
CREATE OR REPLACE TABLE workspace.bronze.PX_CAT_G1V2_bronze AS
SELECT *
FROM read_files(
  '/Volumes/workspace/bronze/source_system/source_erp/PX_CAT_G1V2.csv',
  format => 'csv',
  header => true
);

-- %%
%sql
SELECT * FROM workspace.bronze.PX_CAT_G1V2_bronze;
